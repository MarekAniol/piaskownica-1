# %%
while True:
      print('Who are you?')
      name = input()
      if name != 'Adam':
         continue
      print('Hello, Joe. What is the password? (It is a fish.)')
      password = input()
      if password == 'swordfish':
         break
print('Access granted.')
# Out:
# Who are you?
# Hello, Joe. What is the password? (It is a fish.)
# Who are you?
# Hello, Joe. What is the password? (It is a fish.)
# Access granted.

# %%
print('My name is')
for i in range(5):
    print('Jimmy Five Times (' + str(i) + ')')
# Out:
# My name is
# Jimmy Five Times (0)
# Jimmy Five Times (1)
# Jimmy Five Times (2)
# Jimmy Five Times (3)
# Jimmy Five Times (4)

# %%
total = 0
for num in range(101):
    total += num
print(total)
# Out:
# 5050
# 100

# %%
for i in range(12, 16):
    print(i)
# Out:
# 12
# 13
# 14
# 15

# %%
for i in range(0, 10, 2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(10, -2, -2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2
# 0

# %%
import random
for i in range(5):
    print(random.randint(1, 10))
# Out:
# 1
# 2
# 5
# 2
# 8

# %%
# This is a guess the number game.
import random
secretNumber = random.randint(1, 20)
print('I am thinking of a number between 1 and 20.')

# Ask the player to guess 6 times.
for guessesTaken in range(1, 7):
    print('Take a guess.')
    guess = int(input())

    if guess < secretNumber:
        print('Your guess is too low.')
    elif guess > secretNumber:
        print('Your guess is too high.')
    else:
        break    # This condition is the correct guess!

if guess == secretNumber:
    print('Good job! You guessed my number in ' + str(guessesTaken) + ' guesses!')
else:
    print('Nope. The number I was thinking of was ' + str(secretNumber))
# Out:
# I am thinking of a number between 1 and 20.
# Take a guess.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8fcd61a72727> in <module>
#       7 for guessesTaken in range(1, 7):
#       8     print('Take a guess.')
# ----> 9     guess = int(input())
#      10
#      11     if guess < secretNumber:
#
# ValueError: invalid literal for int() with base 10: 'asd'

# %%
import random, sys

print('ROCK, PAPER, SCISSORS')

# These variables keep track of the number of wins, losses, and ties.
wins = 0
losses = 0
ties = 0

while True: # The main game loop.
    print('%s Wins, %s Losses, %s Ties' % (wins, losses, ties))
    while True: # The player input loop.
        print('Enter your move: (r)ock (p)aper (s)cissors or (q)uit')
        playerMove = input()
        if playerMove == 'q':
            sys.exit() # Quit the program.
        if playerMove == 'r' or playerMove == 'p' or playerMove == 's':
            break # Break out of the player input loop.
        print('Type one of r, p, s, or q.')

    # Display what the player chose:
    if playerMove == 'r':
        print('ROCK versus...')
    elif playerMove == 'p':
        print('PAPER versus...')
    elif playerMove == 's':
        print('SCISSORS versus...')

    # Display what the computer chose:
    randomNumber = random.randint(1, 3)
    if randomNumber == 1:
        computerMove = 'r'
        print('ROCK')
    elif randomNumber == 2:
        computerMove = 'p'
        print('PAPER')
    elif randomNumber == 3:
        computerMove = 's'
        print('SCISSORS')

    # Display and record the win/loss/tie:
    if playerMove == computerMove:
        print('It is a tie!')
        ties = ties + 1
    elif playerMove == 'r' and computerMove == 's':
        print('You win!')
        wins = wins + 1
    elif playerMove == 'p' and computerMove == 'r':
        print('You win!')
        wins = wins + 1
    elif playerMove == 's' and computerMove == 'p':
        print('You win!')
        wins = wins + 1
    elif playerMove == 'r' and computerMove == 'p':
        print('You lose!')
        losses = losses + 1
    elif playerMove == 'p' and computerMove == 's':
        print('You lose!')
        losses = losses + 1
    elif playerMove == 's' and computerMove == 'r':
        print('You lose!')
        losses = losses + 1
# Out:
# ROCK, PAPER, SCISSORS
# 0 Wins, 0 Losses, 0 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# PAPER
# You lose!
# 0 Wins, 1 Losses, 0 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# SCISSORS
# You lose!
# 0 Wins, 2 Losses, 0 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 1 Wins, 2 Losses, 0 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 1 Wins, 3 Losses, 0 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 1 Wins, 3 Losses, 1 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# PAPER
# It is a tie!
# 1 Wins, 3 Losses, 2 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 1 Wins, 3 Losses, 3 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# SCISSORS
# You lose!
# 1 Wins, 4 Losses, 3 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# PAPER
# You lose!
# 1 Wins, 5 Losses, 3 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# PAPER
# You lose!
# 1 Wins, 6 Losses, 3 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# SCISSORS
# You lose!
# 1 Wins, 7 Losses, 3 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 1 Wins, 7 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 2 Wins, 7 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 2 Wins, 8 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# PAPER
# You lose!
# 2 Wins, 9 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# PAPER
# You win!
# 3 Wins, 9 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 4 Wins, 9 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# Type one of r, p, s, or q.
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# SCISSORS
# You lose!
# 4 Wins, 10 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# PAPER
# You win!
# 5 Wins, 10 Losses, 4 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 5 Wins, 10 Losses, 5 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 5 Wins, 10 Losses, 6 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 5 Wins, 11 Losses, 6 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 5 Wins, 12 Losses, 6 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 5 Wins, 13 Losses, 6 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# PAPER
# You win!
# 6 Wins, 13 Losses, 6 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 6 Wins, 13 Losses, 7 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 6 Wins, 13 Losses, 8 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 6 Wins, 13 Losses, 9 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 6 Wins, 13 Losses, 10 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 6 Wins, 14 Losses, 10 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 6 Wins, 15 Losses, 10 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 7 Wins, 15 Losses, 10 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# PAPER
# You lose!
# 7 Wins, 16 Losses, 10 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 7 Wins, 16 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# SCISSORS
# You lose!
# 7 Wins, 17 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# PAPER
# You lose!
# 7 Wins, 18 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# SCISSORS
# You win!
# 8 Wins, 18 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 9 Wins, 18 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# PAPER
# You win!
# 10 Wins, 18 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 11 Wins, 18 Losses, 11 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# Type one of r, p, s, or q.
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# SCISSORS
# It is a tie!
# 11 Wins, 18 Losses, 12 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# Type one of r, p, s, or q.
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# Type one of r, p, s, or q.
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# Type one of r, p, s, or q.
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# ROCK
# It is a tie!
# 11 Wins, 18 Losses, 13 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ROCK versus...
# ROCK
# It is a tie!
# 11 Wins, 18 Losses, 14 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# PAPER versus...
# ROCK
# You win!
# 12 Wins, 18 Losses, 14 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# SCISSORS versus...
# ROCK
# You lose!
# 12 Wins, 19 Losses, 14 Ties
# Enter your move: (r)ock (p)aper (s)cissors or (q)uit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-ea65175f7de0> in <module>
#      12     while True: # The player input loop.
#      13         print('Enter your move: (r)ock (p)aper (s)cissors or (q)uit')
# ---> 14         playerMove = input()
#      15         if playerMove == 'q':
#      16             sys.exit() # Quit the program.
#
# ~/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     852             self._parent_ident,
#     853             self._parent_header,
# --> 854             password=False,
#     855         )
#     856
#
# ~/.local/lib/python3.6/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
